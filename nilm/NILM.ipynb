# %% [markdown]
# ## Preprocessing and EDA

# %% [markdown]
# ## Importing Libraries

# %%
# basic functionalities
import os
import sys
import datetime
import itertools
import math

# data transforamtion and manipulation
import pandas as pd
import numpy as np
from math import sqrt

# prevent crazy long numpy prints
np.set_printoptions(precision=4, suppress=True)

# prevent crazy long pandas prints
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)


# remove warnings
import warnings
warnings.filterwarnings('ignore')


# plotting and plot styling
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go


# set params
plt.rcParams['figure.figsize'] = (16,10)
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['text.color'] = 'k'
plt.style.use('fivethirtyeight')

# statistical modeling libraries
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA, ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX


# ML basic library
from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error, mean_squared_log_error

#Img:
from IPython.display import Image
# Out:
# /var/folders/yp/wh4rvlfs5r5b3n1mdqkp6ypm0000gn/T/ipykernel_11029/1104968003.py:9: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Importing data

# %%
datapath_file = './105_days.parquet'
df = pd.read_parquet(datapath_file)

# %%
df.head()
# Out:
#              DateTime  ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven
# 0 2023-01-01 00:00:00  66116.00000    67088.31250 237.00000 279.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -21.00000        -9.00000             -8.00000         0.00000     0.00000 0.00000
# 1 2023-01-01 00:00:01  66561.00000    68342.31250 237.00000 281.00000        13.00000           -302.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -18.00000         0.00000     0.00000 0.00000
# 2 2023-01-01 00:00:02  66107.00000    67583.31250 237.00000 279.00000        13.00000           -301.00000        16.00000            -55.00000       -16.00000            -22.00000       -13.00000            -13.00000         0.00000     0.00000 0.00000
# 3 2023-01-01 00:00:03  66309.00000    67101.31250 236.00000 281.00000        16.00000           -297.00000        17.00000            -54.00000       -15.00000            -22.00000        -6.00000             -7.00000         0.00000     0.00000 0.00000
# 4 2023-01-01 00:00:04  66309.00000    65259.31250 236.00000 281.00000        15.00000           -300.00000        17.00000            -54.00000       -16.00000            -22.00000        -3.00000            -15.00000         0.00000     0.00000 0.00000

# %%
df.dtypes
# Out:
# DateTime               datetime64[ns]
# ActivePower                   float64
# ReactivePower                 float64
# Voltage                       float64
# Current                       float64
# harmonic1_Real                float64
# harmonic1_Imaginary           float64
# harmonic3_Real                float64
# harmonic3_Imaginary           float64
# harmonic5_Real                float64
# harmonic5_Imaginary           float64
# harmonic7_Real                float64
# harmonic7_Imaginary           float64
# wahing_machine                float64
# dishwasher                    float64
# oven                          float64
# dtype: object

# %%
df['ActivePower'] /= 1000
df['ReactivePower'] /= 1000
df['wahing_machine'] /= 1000
df['dishwasher'] /= 1000
df['oven'] /= 1000

# %% [markdown]
# # Data Preprocessing and Exploratory Data Analysis (EDA)

# %% [markdown]
# ## __Converting to datetime format and sort:__

# %%
# convert:
df['DateTime'] = pd.to_datetime(df['DateTime'])
# sort:
df = df.sort_values(by=['DateTime'], axis=0, ascending=True)
df.dtypes
# Out:
# DateTime               datetime64[ns]
# ActivePower                   float64
# ReactivePower                 float64
# Voltage                       float64
# Current                       float64
# harmonic1_Real                float64
# harmonic1_Imaginary           float64
# harmonic3_Real                float64
# harmonic3_Imaginary           float64
# harmonic5_Real                float64
# harmonic5_Imaginary           float64
# harmonic7_Real                float64
# harmonic7_Imaginary           float64
# wahing_machine                float64
# dishwasher                    float64
# oven                          float64
# dtype: object

# %%
df.shape
# Out:
# (9072000, 16)

# %%
df.head()
# Out:
#              DateTime  ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven
# 0 2023-01-01 00:00:00     66.11600       67.08831 237.00000 279.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -21.00000        -9.00000             -8.00000         0.00000     0.00000 0.00000
# 1 2023-01-01 00:00:01     66.56100       68.34231 237.00000 281.00000        13.00000           -302.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -18.00000         0.00000     0.00000 0.00000
# 2 2023-01-01 00:00:02     66.10700       67.58331 237.00000 279.00000        13.00000           -301.00000        16.00000            -55.00000       -16.00000            -22.00000       -13.00000            -13.00000         0.00000     0.00000 0.00000
# 3 2023-01-01 00:00:03     66.30900       67.10131 236.00000 281.00000        16.00000           -297.00000        17.00000            -54.00000       -15.00000            -22.00000        -6.00000             -7.00000         0.00000     0.00000 0.00000
# 4 2023-01-01 00:00:04     66.30900       65.25931 236.00000 281.00000        15.00000           -300.00000        17.00000            -54.00000       -16.00000            -22.00000        -3.00000            -15.00000         0.00000     0.00000 0.00000

# %%
df.dtypes
# Out:
# DateTime               datetime64[ns]
# ActivePower                   float64
# ReactivePower                 float64
# Voltage                       float64
# Current                       float64
# harmonic1_Real                float64
# harmonic1_Imaginary           float64
# harmonic3_Real                float64
# harmonic3_Imaginary           float64
# harmonic5_Real                float64
# harmonic5_Imaginary           float64
# harmonic7_Real                float64
# harmonic7_Imaginary           float64
# wahing_machine                float64
# dishwasher                    float64
# oven                          float64
# dtype: object

# %%
df.describe()
# Out:
#                             DateTime   ActivePower  ReactivePower       Voltage       Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine    dishwasher          oven
# count                        9072000 9072000.00000  9072000.00000 9072000.00000 9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000   9072000.00000 9072000.00000 9072000.00000
# mean   2023-02-22 11:59:59.499976448     259.92478       72.56988     234.48259     839.26380        -4.40645          -1209.78415        26.10631            -84.17444       -13.41147            -21.86635        -7.03521            -11.00812        13.72150      35.22077      12.01732
# min              2023-01-01 00:00:00       0.00000     -763.30775     226.00000     215.00000     -4074.00000         -28129.00000      -695.00000          -1070.00000      -223.00000           -264.00000      -150.00000           -151.00000         0.00000       0.00000       0.00000
# 25%    2023-01-27 05:59:59.750000128      72.84600       55.77600     233.00000     305.00000       -91.00000           -965.00000        15.00000           -100.00000       -17.00000            -26.00000       -10.00000            -16.00000         0.00000       0.00000       0.00000
# 50%       2023-02-22 11:59:59.500000     132.47700       66.45431     234.00000     560.00000        10.00000           -611.00000        21.00000            -62.00000       -14.00000            -19.00000        -6.00000            -10.00000         0.00000       0.00000       0.00000
# 75%    2023-03-20 17:59:59.249999872     208.37100       79.76900     236.00000     751.00000        46.00000           -331.00000        36.00000            -48.00000        -9.00000            -13.00000        -3.00000             -6.00000         0.00000       0.00000       0.00000
# max              2023-04-15 23:59:59    5962.83200     1590.07625     240.00000   18942.00000      1208.00000             81.00000       487.00000            416.00000       121.00000            183.00000        94.00000             70.00000      1924.37800    2026.09100    1426.67300
# std                              NaN     460.49216       42.52092       1.48292    1167.00240       157.41971           2169.44597        31.10213             60.16534        12.56519             16.32026         7.48746              8.79185       140.09371     257.92428     125.18398

# %% [markdown]
# ## __Removal duplicates__:

# %%
df.drop_duplicates(subset='DateTime', keep='last', inplace=True)

# %%
print('Time period start: {}\nTime period end: {}'.format(df.DateTime.min(),df.DateTime.max()))
# Out:
# Time period start: 2023-01-01 00:00:00
# Time period end: 2023-04-15 23:59:59

# %% [markdown]
# ## __Setting index as the datetime column for easier manipulations:__

# %%
df = df.set_index('DateTime')
print(f'df.index.freq is: {df.index.freq}')
# Out:
# df.index.freq is: None

# %% [markdown]
# __Note:__
# - datetime index's frequency is None => there are some missing data points somewhere (otherwise Python could deduce it) => remove missing

# %% [markdown]
# ## __Find and Fill Missing datetime Instances__

# %%
# ideal range: without missing data
date_range = pd.date_range(start=min(df.index), end=max(df.index), freq='S')

# %%
min(df.index), max(df.index),
# Out:
# (Timestamp('2023-01-01 00:00:00'), Timestamp('2023-04-15 23:59:59'))

# %%
print(f'The difference in length between the ideal date range and our dataset is: {(len(date_range)-len(df))}:')
# Out:
# The difference in length between the ideal date range and our dataset is: 0:

# %%
print("missing data in:", date_range.difference(df.index))
# Out:
# missing data in: DatetimeIndex([], dtype='datetime64[ns]', freq='s')

# %%
#Reindex the dataset and then fill data:

#Create null values in missing data:
df = df.reindex(date_range)

#Filling  missing  with linear interpolation between existing data points
for col in df.columns:
    df[col].interpolate(method='linear', inplace=True)

# now we have a neatly continuous datetime index
print(f'The df.index.freq is now: {df.index.freq}, => we no have missing instances')
# Out:
# The df.index.freq is now: <Second>, => we no have missing instances

# %%
df.head()
# Out:
#                      ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven
# 2023-01-01 00:00:00     66.11600       67.08831 237.00000 279.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -21.00000        -9.00000             -8.00000         0.00000     0.00000 0.00000
# 2023-01-01 00:00:01     66.56100       68.34231 237.00000 281.00000        13.00000           -302.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -18.00000         0.00000     0.00000 0.00000
# 2023-01-01 00:00:02     66.10700       67.58331 237.00000 279.00000        13.00000           -301.00000        16.00000            -55.00000       -16.00000            -22.00000       -13.00000            -13.00000         0.00000     0.00000 0.00000
# 2023-01-01 00:00:03     66.30900       67.10131 236.00000 281.00000        16.00000           -297.00000        17.00000            -54.00000       -15.00000            -22.00000        -6.00000             -7.00000         0.00000     0.00000 0.00000
# 2023-01-01 00:00:04     66.30900       65.25931 236.00000 281.00000        15.00000           -300.00000        17.00000            -54.00000       -16.00000            -22.00000        -3.00000            -15.00000         0.00000     0.00000 0.00000

# %%
df.shape
# Out:
# (9072000, 15)

# %% [markdown]
# ## Extracting Time Features
#
# - We split datetime into its different __features__ => to find patterns for different groups.

# %%
df['dayofweek'] = df.index.dayofweek
df['dayofyear'] = df.index.dayofyear
df['year'] = df.index.year
df['month'] = df.index.month
df['quarter'] = df.index.quarter
df['hour'] = df.index.hour
df['weekday'] = df.index.weekday
df['weekofyear'] = df.index.dayofyear//7
df['dayofmonth'] = df.index.day # Day of Month
df['date'] = df.index.date

# let's add the season number
df['season'] = df['month'].apply(lambda month_number: (month_number%12 + 3)//3)

# %%
df.head()
# Out:
#                      ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven  dayofweek  dayofyear  year  month  quarter  hour  weekday  weekofyear  dayofmonth        date  season
# 2023-01-01 00:00:00     66.11600       67.08831 237.00000 279.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -21.00000        -9.00000             -8.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:01     66.56100       68.34231 237.00000 281.00000        13.00000           -302.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -18.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:02     66.10700       67.58331 237.00000 279.00000        13.00000           -301.00000        16.00000            -55.00000       -16.00000            -22.00000       -13.00000            -13.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:03     66.30900       67.10131 236.00000 281.00000        16.00000           -297.00000        17.00000            -54.00000       -15.00000            -22.00000        -6.00000             -7.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:04     66.30900       65.25931 236.00000 281.00000        15.00000           -300.00000        17.00000            -54.00000       -16.00000            -22.00000        -3.00000            -15.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1

# %%
df.tail()
# Out:
#                      ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven  dayofweek  dayofyear  year  month  quarter  hour  weekday  weekofyear  dayofmonth        date  season
# 2023-04-15 23:59:55    138.89600      140.49139 235.00000 597.00000      -123.00000           -642.00000        17.00000            -41.00000       -17.00000            -11.00000       -12.00000             -7.00000         0.00000     0.00000 0.00000          5        105  2023      4        2    23        5          15          15  2023-04-15       2
# 2023-04-15 23:59:56    139.57400      139.00139 235.00000 599.00000      -126.00000           -642.00000        19.00000            -42.00000       -16.00000            -11.00000        -6.00000              0.00000         0.00000     0.00000 0.00000          5        105  2023      4        2    23        5          15          15  2023-04-15       2
# 2023-04-15 23:59:57    138.99700      140.66539 236.00000 595.00000      -127.00000           -639.00000        16.00000            -42.00000       -17.00000            -10.00000        -4.00000             -7.00000         0.00000     0.00000 0.00000          5        105  2023      4        2    23        5          15          15  2023-04-15       2
# 2023-04-15 23:59:58    141.10800      139.17039 236.00000 603.00000      -125.00000           -649.00000        19.00000            -44.00000       -17.00000            -12.00000       -12.00000             -2.00000         0.00000     0.00000 0.00000          5        105  2023      4        2    23        5          15          15  2023-04-15       2
# 2023-04-15 23:59:59    137.68200      142.25639 235.00000 593.00000      -124.00000           -639.00000        18.00000            -43.00000       -16.00000            -11.00000        -2.00000             -3.00000         0.00000     0.00000 0.00000          5        105  2023      4        2    23        5          15          15  2023-04-15       2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
gr_hour_season = df.groupby(['hour', 'season']).agg({'ActivePower':'median'})
gr_hour_season.head()
# Out:
#              ActivePower
# hour season
# 0    1         110.22400
#      2         114.05100
# 1    1          66.42000
#      2          66.28500
# 2    1          65.08800

# %%
gr_dayofweek_season = df.groupby(['dayofweek', 'season'], as_index=False).agg({'ActivePower':'median'})
gr_dayofweek_season.head()
# Out:
#    dayofweek  season  ActivePower
# 0          0       1    132.01750
# 1          0       2    129.06300
# 2          1       1    134.86100
# 3          1       2    132.32500
# 4          2       1    132.14000

# %%
gr_dayofweek_season['dayofweek_name'] = gr_dayofweek_season.dayofweek.map({ 0:'lunedi',
                                                                            1:'martedi',
                                                                            2:'mercoledi',
                                                                            3:'giovedi',
                                                                            4:'venerdi',
                                                                            5:'sabato',
                                                                            6:'domenica',
                                                                         })

# %%
gr_dayofweek_season.head()
# Out:
#    dayofweek  season  ActivePower dayofweek_name
# 0          0       1    132.01750         lunedi
# 1          0       2    129.06300         lunedi
# 2          1       1    134.86100        martedi
# 3          1       2    132.32500        martedi
# 4          2       1    132.14000      mercoledi

# %% [markdown]
# ## Applying denoising filter

# %% [markdown]
# ### Median Filter

# %%
import pandas as pd
from scipy.signal import medfilt
import matplotlib.pyplot as plt

# Specify the columns you want to filter
columns_to_filter = ['ActivePower', 'ReactivePower', 'Voltage', 'Current', 'harmonic1_Real', 'harmonic1_Imaginary', 'harmonic3_Real', 'harmonic3_Imaginary', 'harmonic5_Real',
                     'harmonic5_Imaginary', 'harmonic7_Real', 'harmonic7_Imaginary']

# Set a window size for the median filter
window_size = 5  # Adjust this based on your data characteristics

# Apply median filter to specified columns
for col in columns_to_filter:
    df[f'{col}'] = medfilt(df[col], kernel_size=window_size)

# %% [markdown]
# ## Unbalanced data

# %%
y_wm = (df['wahing_machine']>0).astype(int)
y_dw = (df['dishwasher']>0).astype(int)
y_ow = (df['oven']>0).astype(int)

# %%
drop_cols = ['wahing_machine', 'dishwasher', 'oven', 'date']
X =  df.drop(drop_cols, axis=1)

# %%
X.dtypes
# Out:
# ActivePower            float64
# ReactivePower          float64
# Voltage                float64
# Current                float64
# harmonic1_Real         float64
# harmonic1_Imaginary    float64
# harmonic3_Real         float64
# harmonic3_Imaginary    float64
# harmonic5_Real         float64
# harmonic5_Imaginary    float64
# harmonic7_Real         float64
# harmonic7_Imaginary    float64
# dayofweek                int32
# dayofyear                int32
# year                     int32
# month                    int32
# quarter                  int32
# hour                     int32
# weekday                  int32
# weekofyear               int32
# dayofmonth               int32
# season                   int64
# dtype: object

# %%
X.describe()
# Out:
#         ActivePower  ReactivePower       Voltage       Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary     dayofweek     dayofyear          year         month       quarter          hour       weekday    weekofyear    dayofmonth        season
# count 9072000.00000  9072000.00000 9072000.00000 9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000   9072000.00000        9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000 9072000.00000
# mean      259.58305       72.47731     234.49028     837.91506        -4.05757          -1208.16823        26.18319            -83.98150       -13.36833            -21.80158        -6.99258            -10.97825       3.00000      53.00000    2023.00000       2.28571       1.14286      11.50000       3.00000       7.14286      14.45714       1.43810
# std       459.95585       41.89634       1.47188    1164.42375       154.58841           2166.91119        30.68682             59.75507        12.13308             16.19231         6.70211              8.28736       2.00000      30.30952       0.00000       1.03936       0.34993       6.92219       2.00000       4.33464       8.64102       0.49615
# min        50.76000      -17.06175     228.00000     217.00000     -2566.00000         -27738.00000      -679.00000          -1059.00000      -210.00000           -214.00000      -100.00000            -96.00000       0.00000       1.00000    2023.00000       1.00000       1.00000       0.00000       0.00000       0.00000       1.00000       1.00000
# 25%        72.84800       55.88500     233.00000     305.00000       -91.00000           -965.00000        15.00000           -100.00000       -17.00000            -26.00000        -9.00000            -15.00000       1.00000      27.00000    2023.00000       1.00000       1.00000       5.75000       1.00000       3.00000       7.00000       1.00000
# 50%       132.39000       66.46931     234.00000     560.00000        10.00000           -610.00000        21.00000            -62.00000       -14.00000            -19.00000        -6.00000            -10.00000       3.00000      53.00000    2023.00000       2.00000       1.00000      11.50000       3.00000       7.00000      14.00000       1.00000
# 75%       208.17700       79.75431     236.00000     749.00000        46.00000           -331.00000        36.00000            -48.00000        -9.00000            -13.00000        -4.00000             -6.00000       5.00000      79.00000    2023.00000       3.00000       1.00000      17.25000       5.00000      11.00000      22.00000       2.00000
# max      5881.18000      688.38816     240.00000   15171.00000       766.00000           -234.00000       477.00000            225.00000        62.00000            136.00000        24.00000             46.00000       6.00000     105.00000    2023.00000       4.00000       2.00000      23.00000       6.00000      15.00000      31.00000       2.00000

# %%
y_wm.head()
# Out:
# 2023-01-01 00:00:00    0
# 2023-01-01 00:00:01    0
# 2023-01-01 00:00:02    0
# 2023-01-01 00:00:03    0
# 2023-01-01 00:00:04    0
# Freq: s, Name: wahing_machine, dtype: int64

# %%
y_wm.value_counts()
# Out:
# wahing_machine
# 0    8774256
# 1     297744
# Name: count, dtype: int64

# %%
y_dw.value_counts()
# Out:
# dishwasher
# 0    8830898
# 1     241102
# Name: count, dtype: int64

# %%
y_ow.value_counts()
# Out:
# oven
# 0    8960338
# 1     111662
# Name: count, dtype: int64

# %%
y_wm_month = pd.concat([y_wm, df['month']], axis=1)

# %%
print(y_wm_month.groupby(['month', 'wahing_machine']).size().unstack(fill_value=0))
# Out:
# wahing_machine        0      1
# month
# 1               2583183  95217
# 2               2356011  63189
# 3               2580667  97733
# 4               1254395  41605

# %%
y_dw_month = pd.concat([y_dw, df['month']], axis=1)

# %%
print(y_dw_month.groupby(['month', 'dishwasher']).size().unstack(fill_value=0))
# Out:
# dishwasher        0      1
# month
# 1           2618104  60296
# 2           2348096  71104
# 3           2600666  77734
# 4           1264032  31968

# %%
y_ow_month = pd.concat([y_ow, df['month']], axis=1)

# %%
print(y_ow_month.groupby(['month', 'oven']).size().unstack(fill_value=0))
# Out:
# oven         0      1
# month
# 1      2643219  35181
# 2      2388382  30818
# 3      2648033  30367
# 4      1280704  15296

# %%
print(y_ow_month.groupby(['month', 'oven']).size().unstack(fill_value=0))
# Out:
# oven         0      1
# month
# 1      2643219  35181
# 2      2388382  30818
# 3      2648033  30367
# 4      1280704  15296

# %%
Y = pd.concat([y_wm, y_dw, y_ow], axis=1)

# %%
Y.head()
# Out:
#                      wahing_machine  dishwasher  oven
# 2023-01-01 00:00:00               0           0     0
# 2023-01-01 00:00:01               0           0     0
# 2023-01-01 00:00:02               0           0     0
# 2023-01-01 00:00:03               0           0     0
# 2023-01-01 00:00:04               0           0     0

# %%
Y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='wahing_machine,dishwasher,oven'>

# %%
Y['label'] = Y[['wahing_machine','dishwasher','oven']].apply(lambda row: int(''.join(map(str, row)), 2), axis=1)

# %%
print(Y[Y['label']==4])
# Out:
#                      wahing_machine  dishwasher  oven  label
# 2023-01-02 18:04:27               1           0     0      4
# 2023-01-02 18:04:28               1           0     0      4
# 2023-01-02 18:04:29               1           0     0      4
# 2023-01-02 18:04:30               1           0     0      4
# 2023-01-02 18:04:31               1           0     0      4
# ...                             ...         ...   ...    ...
# 2023-04-15 08:36:14               1           0     0      4
# 2023-04-15 08:36:27               1           0     0      4
# 2023-04-15 08:36:28               1           0     0      4
# 2023-04-15 08:36:29               1           0     0      4
# 2023-04-15 08:36:34               1           0     0      4
#
# [238119 rows x 4 columns]

# %%
Y['label_str'] = Y['label'].map({0:'AO',
                                1:'OW',
                                2:'DW',
                                3:'DW_OW',
                                4:'WM',
                                5:'WM_OW',
                                6:'WM_DW',
                                7:'WM_DW_OW',
                                })
Y['label_str']
# Out:
# 2023-01-01 00:00:00    AO
# 2023-01-01 00:00:01    AO
# 2023-01-01 00:00:02    AO
# 2023-01-01 00:00:03    AO
# 2023-01-01 00:00:04    AO
#                        ..
# 2023-04-15 23:59:55    AO
# 2023-04-15 23:59:56    AO
# 2023-04-15 23:59:57    AO
# 2023-04-15 23:59:58    AO
# 2023-04-15 23:59:59    AO
# Freq: s, Name: label_str, Length: 9072000, dtype: object

# %%
y_analysis = pd.concat([Y, df['ActivePower'], df['ReactivePower'], df['harmonic1_Real'], df['harmonic1_Imaginary'], df['harmonic3_Real'], df['harmonic3_Imaginary'], df['harmonic5_Real'], df['harmonic5_Imaginary'], df['harmonic7_Real'], df['harmonic7_Imaginary'], df['Voltage'], df['Current']], axis=1)

# %% [markdown]
# ## Add a new features

# %% [markdown]
# ### Instant Power

# %%
y_analysis['instant_power'] = y_analysis['ActivePower'] * y_analysis['ReactivePower']

# %% [markdown]
# ### Apparent Power

# %%
y_analysis['ApparentPower'] = (y_analysis['ActivePower']**2 + y_analysis['ReactivePower']**2)**0.5

# %% [markdown]
# ### Power Factor

# %%
y_analysis['PowerFactor'] = np.cos(np.arccos(y_analysis['ActivePower'] / y_analysis['ApparentPower']))

# %% [markdown]
# ### Total Harmonic Distortion (THD)

# %%
harmonics_columns = ['harmonic1_Real', 'harmonic1_Imaginary', 'harmonic3_Real', 'harmonic3_Imaginary',
                     'harmonic5_Real', 'harmonic5_Imaginary', 'harmonic7_Real', 'harmonic7_Imaginary']

harmonics_square_sum = np.sum(y_analysis[harmonics_columns] ** 2, axis=1)
y_analysis['THD'] = np.sqrt(harmonics_square_sum) / y_analysis['ActivePower']

# %% [markdown]
# ### Harmonic Distortion Index

# %%
y_analysis['HarmonicDistortionIndex'] = np.sum(np.sqrt(y_analysis[harmonics_columns] ** 2), axis=1)

# %% [markdown]
# ### Power Fluctuation

# %%
y_analysis['Power Fluctuations'] = y_analysis['ActivePower'].diff() / y_analysis.index.to_series().diff().dt.total_seconds()

# Fill NaN values in the first row (resulting from the diff operation)
y_analysis['Power Fluctuations'].iloc[0] = 0.0

# %% [markdown]
# ### Resistance

# %%
y_analysis['Resistance'] = y_analysis['Voltage'] / y_analysis['Current']

# %%
y_analysis.head()
# Out:
#                      wahing_machine  dishwasher  oven  label label_str  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary   Voltage   Current  instant_power  ApparentPower  PowerFactor     THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# 2023-01-01 00:00:00               0           0     0      0        AO     66.10700       67.08831        13.00000           -300.00000        16.00000            -55.00000       -16.00000            -21.00000        -6.00000             -8.00000 237.00000 279.00000     4435.00707       94.18586      0.70188 4.64394                435.00000             0.00000     0.84946
# 2023-01-01 00:00:01               0           0     0      0        AO     66.11600       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000             -8.00000 237.00000 279.00000     4436.47038       94.20144      0.70186 4.64518                437.00000             0.00900     0.84946
# 2023-01-01 00:00:02               0           0     0      0        AO     66.30900       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -13.00000 237.00000 281.00000     4449.42093       94.33700      0.70289 4.63423                442.00000             0.19300     0.84342
# 2023-01-01 00:00:03               0           0     0      0        AO     66.30900       67.10131        15.00000           -301.00000        17.00000            -54.00000       -16.00000            -22.00000        -6.00000            -15.00000 236.00000 281.00000     4449.42093       94.33700      0.70289 4.64903                446.00000             0.00000     0.83986
# 2023-01-01 00:00:04               0           0     0      0        AO     66.30900       65.99931        15.00000           -301.00000        16.00000            -54.00000       -16.00000            -22.00000        -9.00000            -15.00000 236.00000 281.00000     4376.34841       93.55636      0.70876 4.64932                448.00000             0.00000     0.83986

# %%
# List of column names to drop
columns_to_drop = ['wahing_machine', 'dishwasher', 'oven', 'label', 'label_str']

# Dropping columns
x_analysis = y_analysis.drop(columns=columns_to_drop)

# %%
x_analysis.head()
# Out:
#                      ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary   Voltage   Current  instant_power  ApparentPower  PowerFactor     THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# 2023-01-01 00:00:00     66.10700       67.08831        13.00000           -300.00000        16.00000            -55.00000       -16.00000            -21.00000        -6.00000             -8.00000 237.00000 279.00000     4435.00707       94.18586      0.70188 4.64394                435.00000             0.00000     0.84946
# 2023-01-01 00:00:01     66.11600       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000             -8.00000 237.00000 279.00000     4436.47038       94.20144      0.70186 4.64518                437.00000             0.00900     0.84946
# 2023-01-01 00:00:02     66.30900       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -13.00000 237.00000 281.00000     4449.42093       94.33700      0.70289 4.63423                442.00000             0.19300     0.84342
# 2023-01-01 00:00:03     66.30900       67.10131        15.00000           -301.00000        17.00000            -54.00000       -16.00000            -22.00000        -6.00000            -15.00000 236.00000 281.00000     4449.42093       94.33700      0.70289 4.64903                446.00000             0.00000     0.83986
# 2023-01-01 00:00:04     66.30900       65.99931        15.00000           -301.00000        16.00000            -54.00000       -16.00000            -22.00000        -9.00000            -15.00000 236.00000 281.00000     4376.34841       93.55636      0.70876 4.64932                448.00000             0.00000     0.83986

# %%
# Assuming your DataFrame is named df
labels_to_visualize = [1, 2, 4]

# Filter the DataFrame for the specified labels
filtered_df = y_analysis[y_analysis['label'].isin(labels_to_visualize)]

# Group by 'label' and calculate the mean of 'ActivePower'
mean_by_label = filtered_df.groupby('label')['ActivePower'].mean()

# Plot the mean values
mean_by_label.plot(kind='bar', color='skyblue')
plt.xlabel('Label')
plt.ylabel('Mean ActivePower')
plt.title('Mean ActivePower for Selected Labels')
plt.show()

# %%
labels_to_describe = [1, 2, 3, 4, 5, 6, 7]

# Iterate through each label and apply describe
for label in labels_to_describe:
    label_df = y_analysis[y_analysis['label'] == label]
    label_description = label_df.describe()
    print(f"Description for Label {label}:\n{label_description}\n")
# Out:
# Description for Label 1:
#        wahing_machine  dishwasher        oven       label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary     Voltage     Current  instant_power  ApparentPower  PowerFactor         THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# count     69501.00000 69501.00000 69501.00000 69501.00000  69501.00000    69501.00000     69501.00000          69501.00000     69501.00000          69501.00000     69501.00000          69501.00000     69501.00000          69501.00000 69501.00000 69501.00000    69501.00000    69501.00000  69501.00000 69501.00000              69501.00000         69501.00000 69501.00000
# mean          0.00000     0.00000     1.00000     1.00000   1401.43239      156.05948      -265.78697          -6604.30355        62.33523           -147.09026       -11.24535            -34.09767       -12.84110            -16.17916   233.69767  2124.48886   223803.24130     1416.80613      0.97056     4.74034               7178.50986             0.45689     0.34775
# std           0.00000     0.00000     0.00000     0.00000    695.38010       61.71098       254.69609           3298.23645        24.43516             53.86651        12.04792             17.42048         6.12755              9.09258     1.57743  2624.30828   156878.00247      684.38963      0.05198     0.11288               3309.47418           126.05882     0.26596
# min           0.00000     0.00000     1.00000     1.00000    104.75400        4.98373     -2181.00000         -18424.00000        14.00000           -807.00000      -116.00000            -91.00000       -35.00000            -51.00000   229.00000   246.00000     2749.45042      114.80983      0.71594     1.13781                754.00000         -1357.66200     0.01955
# 25%           0.00000     0.00000     1.00000     1.00000   1415.37700      113.24913      -469.00000          -7912.00000        44.00000           -182.00000       -19.00000            -46.00000       -17.00000            -22.00000   233.00000   509.00000    89048.83251     1416.49763      0.98633     4.70896               6969.00000            -0.44700     0.15631
# 50%           0.00000     0.00000     1.00000     1.00000   1583.05100      148.84491      -208.00000          -7465.00000        59.00000           -143.00000       -11.00000            -33.00000       -13.00000            -15.00000   234.00000   679.00000   211420.32712     1588.88078      0.99440     4.72795               7948.00000             0.00000     0.34462
# 75%           0.00000     0.00000     1.00000     1.00000   1679.18300      197.23181       -83.00000          -6735.00000        77.00000           -105.00000        -3.00000            -23.00000        -9.00000             -9.00000   235.00000  1497.00000   315286.96929     1689.21465      0.99716     4.74806               8578.00000             0.00600     0.45776
# max           0.00000     0.00000     1.00000     1.00000   3897.40700      361.03184       421.00000           -474.00000       388.00000            -29.00000        31.00000             23.00000        14.00000             12.00000   238.00000 11865.00000  1015547.67828     3902.59975      0.99999    10.40998              19217.00000          1665.73600     0.95200
#
# Description for Label 2:
#        wahing_machine   dishwasher         oven        label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary      Voltage      Current  instant_power  ApparentPower  PowerFactor          THD  HarmonicDistortionIndex  Power Fluctuations   Resistance
# count    182445.00000 182445.00000 182445.00000 182445.00000 182445.00000   182445.00000    182445.00000         182445.00000    182445.00000         182445.00000    182445.00000         182445.00000    182445.00000         182445.00000 182445.00000 182445.00000   182445.00000   182445.00000 182445.00000 182445.00000             182445.00000        182445.00000 182445.00000
# mean          0.00000      1.00000      0.00000      2.00000   1676.07120      124.20905       109.75575          -7886.89917        72.47848           -277.72134        -6.04797            -71.87319        -8.01075            -36.63890    234.08929   1899.41900   207695.32205     1686.01122      0.97940      4.70596               8574.61338            -0.22087      0.36823
# std           0.00000      0.00000      0.00000      0.00000    934.16803       46.94310       227.69694           4431.98464        34.03446             75.20755        18.64272             21.20528         9.20954             11.29035      1.49370   2729.86552   149786.44509      925.67932      0.04075      0.04936               4446.41330            91.77427      0.26027
# min           0.00000      1.00000      0.00000      2.00000     69.88400       -0.16075     -1863.00000         -21420.00000        -9.00000           -985.00000      -115.00000           -132.00000       -47.00000            -76.00000    229.00000    246.00000     -336.48110      116.59773      0.46206      1.46932                454.00000         -1841.54700      0.01617
# 25%           0.00000      1.00000      0.00000      2.00000    517.28600       91.50650       -52.00000         -10616.00000        47.00000           -326.00000       -18.00000            -87.00000       -14.00000            -45.00000    233.00000    480.00000    66402.94069      534.35158      0.97989      4.68329               3284.00000            -0.26800      0.18097
# 50%           0.00000      1.00000      0.00000      2.00000   2080.11700      124.31500       116.00000          -9818.00000        70.00000           -266.00000        -6.00000            -72.00000        -7.00000            -36.00000    234.00000    667.00000   198903.40256     2086.25937      0.99763      4.71098              10334.00000             0.00000      0.35082
# 75%           0.00000      1.00000      0.00000      2.00000   2247.18300      156.40306       268.00000          -2378.00000        96.00000           -224.00000         7.00000            -57.00000        -1.00000            -29.00000    235.00000   1297.00000   308863.29718     2250.60141      0.99897      4.73214              11423.00000             0.16800      0.48542
# max           0.00000      1.00000      0.00000      2.00000   4525.24700      310.07000       766.00000           -322.00000       407.00000            -60.00000        52.00000             21.00000        24.00000              4.00000    238.00000  14274.00000  1025843.68335     4525.60270      1.00000      6.54095              22507.00000          1828.26700      0.95968
#
# Description for Label 3:
#        wahing_machine  dishwasher        oven       label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary     Voltage     Current  instant_power  ApparentPower  PowerFactor         THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# count     20340.00000 20340.00000 20340.00000 20340.00000  20340.00000    20340.00000     20340.00000          20340.00000     20340.00000          20340.00000     20340.00000          20340.00000     20340.00000          20340.00000 20340.00000 20340.00000    20340.00000    20340.00000  20340.00000 20340.00000              20340.00000         20340.00000 20340.00000
# mean          0.00000     1.00000     1.00000     3.00000   3040.59469      224.62297      -145.90251         -14328.71219       117.96878           -358.48358        -6.97463            -94.39199       -16.75187            -44.84464   234.02493   890.30034   683499.95148     3051.80718      0.99268     4.71089              15226.04966             1.57945     0.49576
# std           0.00000     0.00000     0.00000     0.00000    991.89369       63.32720       277.53750           4710.10433        36.34774             69.62675        20.11351             23.10023         9.58500             12.30772     1.48626  1240.09956   315492.05595      984.88935      0.01889     0.04297               4705.15915           151.90103     0.26352
# min           0.00000     1.00000     1.00000     3.00000    359.86400       93.36372     -2077.00000         -23515.00000        27.00000          -1059.00000       -94.00000           -194.00000       -52.00000            -96.00000   230.00000   252.00000    65764.94907      405.67671      0.84579     2.49610               2276.00000         -1835.43700     0.04091
# 25%           0.00000     1.00000     1.00000     3.00000   2192.29600      182.06858      -380.00000         -17541.00000        93.00000           -400.00000       -18.00000           -110.00000       -22.00000            -54.00000   233.00000   328.00000   471492.43537     2199.81538      0.99466     4.69944              11087.75000            -0.64200     0.33003
# 50%           0.00000     1.00000     1.00000     3.00000   3534.58250      216.15200       -94.00000         -16689.00000       114.00000           -359.00000        -7.00000            -94.00000       -17.00000            -46.00000   234.00000   570.00000   648213.67744     3547.11619      0.99756     4.71705              17442.00000             0.00000     0.41197
# 75%           0.00000     1.00000     1.00000     3.00000   3717.64800      256.78567        54.00000         -10335.00000       143.00000           -306.00000         5.00000            -77.00000       -10.00000            -36.00000   235.00000   706.00000   864029.17847     3724.97265      0.99857     4.73056              18458.00000             0.23400     0.70909
# max           0.00000     1.00000     1.00000     3.00000   4966.53400      483.03394       504.00000          -1644.00000       477.00000           -213.00000        62.00000            -18.00000        18.00000             -3.00000   238.00000  5647.00000  2290294.78791     4972.59594      0.99970     5.57541              25518.00000          1825.30200     0.94444
#
# Description for Label 4:
#        wahing_machine   dishwasher         oven        label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary      Voltage      Current  instant_power  ApparentPower  PowerFactor          THD  HarmonicDistortionIndex  Power Fluctuations   Resistance
# count    238119.00000 238119.00000 238119.00000 238119.00000 238119.00000   238119.00000    238119.00000         238119.00000    238119.00000         238119.00000    238119.00000         238119.00000    238119.00000         238119.00000 238119.00000 238119.00000   238119.00000   238119.00000 238119.00000 238119.00000             238119.00000        238119.00000 238119.00000
# mean          1.00000      0.00000      0.00000      4.00000    791.43630      153.29111      -105.34051          -3691.67839        -8.99715           -152.10770       -52.44537            -39.74929       -29.59348            -12.37791    234.60680   1358.91045   123899.86680      825.68100      0.88076      4.69847               4158.77017             1.18234      0.43071
# std           0.00000      0.00000      0.00000      0.00000    831.64231       54.59501       176.70348           3915.59885        49.79949             64.92005        27.63810             19.43566        12.33247              8.48601      1.51766   2164.12662   142823.44290      814.08223      0.11434      0.08931               3890.84376            82.47488      0.25762
# min           1.00000      0.00000      0.00000      4.00000     61.49900       18.78194     -2083.00000         -20005.00000      -679.00000           -792.00000      -184.00000           -137.00000       -87.00000            -45.00000    230.00000    246.00000     1920.97377       69.21032      0.37430      0.41984                409.00000         -1743.70800      0.01716
# 25%           1.00000      0.00000      0.00000      4.00000    198.67750      117.45504      -195.00000          -6970.00000       -31.00000           -187.00000       -70.00000            -52.00000       -37.00000            -18.00000    234.00000    386.00000    28330.18436      251.60899      0.81464      4.66462               1353.00000            -0.49500      0.26381
# 50%           1.00000      0.00000      0.00000      4.00000    303.15000      150.59503      -103.00000          -1387.00000        -7.00000           -146.00000       -52.00000            -39.00000       -29.00000            -12.00000    235.00000    614.00000    52321.99645      356.28755      0.89478      4.69309               1992.00000             0.00000      0.38134
# 75%           1.00000      0.00000      0.00000      4.00000   1492.22800      186.38025         6.00000           -905.00000        21.00000           -107.00000       -32.00000            -28.00000       -20.00000             -7.00000    236.00000    889.00000   210186.32068     1506.44047      0.99385      4.72722               7584.00000             1.18800      0.60881
# max           1.00000      0.00000      0.00000      4.00000   4251.70300      555.92053       421.00000           -279.00000       351.00000            172.00000        15.00000            115.00000         6.00000             36.00000    239.00000  13465.00000  1842465.07043     4256.53978      0.99998     10.56174              20250.00000          1734.43800      0.95968
#
# Description for Label 5:
#        wahing_machine  dishwasher        oven       label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary     Voltage     Current  instant_power  ApparentPower  PowerFactor         THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# count     21308.00000 21308.00000 21308.00000 21308.00000  21308.00000    21308.00000     21308.00000          21308.00000     21308.00000          21308.00000     21308.00000          21308.00000     21308.00000          21308.00000 21308.00000 21308.00000    21308.00000    21308.00000  21308.00000 21308.00000              21308.00000         21308.00000 21308.00000
# mean          1.00000     0.00000     1.00000     5.00000   2058.63507      299.69073      -433.79200          -9674.80707        34.13051           -255.70560       -60.06725            -61.35372       -40.76089            -23.28205   234.26239   843.99643   623651.12282     2093.27239      0.96164     4.71759              10624.64286             0.90699     0.48077
# std           0.00000     0.00000     0.00000     0.00000   1161.76255       84.38573       331.94308           5501.79738        69.10209             76.26734        31.23585             30.96674        12.92577             11.32152     1.38392  1153.61579   407457.94294     1141.40888      0.05971     0.05988               5466.43875           157.57183     0.23583
# min           1.00000     0.00000     1.00000     5.00000    324.82500       87.28985     -2102.00000         -27738.00000      -564.00000           -612.00000      -173.00000           -175.00000       -96.00000            -61.00000   230.00000   246.00000    51927.24731      366.67350      0.72327     1.93266               2076.00000         -2096.68500     0.04117
# 25%           1.00000     0.00000     1.00000     5.00000   1664.61650      233.70392      -666.25000         -13854.00000         8.00000           -297.00000       -82.00000            -80.00000       -50.00000            -31.00000   233.00000   367.00000   343912.02584     1686.13268      0.97457     4.69775               8548.00000            -1.11525     0.33477
# 50%           1.00000     0.00000     1.00000     5.00000   1825.73800      286.34184      -374.00000          -8581.00000        42.00000           -254.00000       -60.00000            -67.00000       -40.00000            -24.00000   234.00000   546.00000   548910.65488     1853.36775      0.98890     4.71330               9543.00000             0.00000     0.43040
# 75%           1.00000     0.00000     1.00000     5.00000   2937.60100      363.71578      -207.00000          -7839.00000        73.00000           -214.00000       -37.00000            -48.00000       -31.00000            -16.00000   235.00000   698.00000   817299.24828     2953.16848      0.99458     4.73016              14804.00000             0.64125     0.64033
# max           1.00000     0.00000     1.00000     5.00000   5881.18000      640.94194       410.00000          -1450.00000       236.00000             70.00000        16.00000            134.00000        -4.00000             46.00000   238.00000  5659.00000  2297083.35064     5882.05830      0.99989     6.37133              28462.00000          1710.48800     0.95565
#
# Description for Label 6:
#        wahing_machine  dishwasher        oven       label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary     Voltage     Current  instant_power  ApparentPower  PowerFactor         THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# count     37804.00000 37804.00000 37804.00000 37804.00000  37804.00000    37804.00000     37804.00000          37804.00000     37804.00000          37804.00000     37804.00000          37804.00000     37804.00000          37804.00000 37804.00000 37804.00000    37804.00000    37804.00000  37804.00000 37804.00000              37804.00000         37804.00000 37804.00000
# mean          1.00000     1.00000     0.00000     6.00000   2414.65684      278.36258      -126.15242         -11346.62525        30.50296           -384.28886       -61.25698           -104.68411       -39.34695            -41.83896   234.10052   735.89969   671151.54961     2440.54855      0.97240     4.69810              12271.97884             0.41685     0.49059
# std           0.00000     0.00000     0.00000     0.00000   1148.52870       65.74468       270.59529           5434.58608        63.80491             87.43088        34.64622             26.16092        16.21832             13.21577     1.49379   932.07793   364222.82162     1129.25437      0.04917     0.03978               5431.45586           129.70925     0.22911
# min           1.00000     1.00000     0.00000     6.00000    284.18900       44.50213     -1889.00000         -24957.00000      -608.00000           -737.00000      -210.00000           -214.00000       -98.00000            -82.00000   230.00000   246.00000    19713.77384      404.43996      0.69045     3.33085               1900.00000         -1793.67000     0.04142
# 25%           1.00000     1.00000     0.00000     6.00000   2110.23700      238.23153      -315.00000         -16192.00000        -3.00000           -442.00000       -84.00000           -121.25000       -51.00000            -51.00000   233.00000   361.00000   475788.24489     2126.43279      0.98774     4.68347              10616.75000            -0.84225     0.34933
# 50%           1.00000     1.00000     0.00000     6.00000   2355.29900      268.92294      -142.00000         -11079.00000        35.00000           -375.00000       -59.00000           -105.00000       -38.00000            -41.00000   234.00000   544.00000   636264.20347     2374.08981      0.99414     4.70425              12070.00000             0.00000     0.43333
# 75%           1.00000     1.00000     0.00000     6.00000   3441.14200      318.70737        64.00000          -9927.75000        70.00000           -320.00000       -35.00000            -89.00000       -27.00000            -33.00000   235.00000   671.00000   901302.63867     3453.20509      0.99652     4.72078              17046.00000             0.99050     0.65374
# max           1.00000     1.00000     0.00000     6.00000   5288.97200      688.38816       558.00000          -1284.00000       184.00000            -35.00000        21.00000             46.00000         3.00000             10.00000   239.00000  5649.00000  2109678.46920     5298.07186      0.99977     6.13452              26136.00000          1815.70100     0.95935
#
# Description for Label 7:
#        wahing_machine  dishwasher      oven     label  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary   Voltage   Current  instant_power  ApparentPower  PowerFactor       THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# count       513.00000   513.00000 513.00000 513.00000    513.00000      513.00000       513.00000            513.00000       513.00000            513.00000       513.00000            513.00000       513.00000            513.00000 513.00000 513.00000      513.00000      513.00000    513.00000 513.00000                513.00000           513.00000   513.00000
# mean          1.00000     1.00000   1.00000   7.00000   3453.33395      400.88011      -546.98635         -16220.04873        60.89279           -426.48343       -74.23392           -115.13255       -54.25341            -40.62183 235.41520 425.68421  1384589.29617     3478.58495      0.99152   4.70047              17551.29630             7.50279     0.59916
# std           0.00000     0.00000   0.00000   0.00000    880.92069       43.38807       114.82191           4162.39786        63.11184             63.58929        36.25253             16.53943        17.67486             11.13681   0.63209 118.07994   374444.68735      873.80932      0.00625   0.01979               4143.45186           185.76702     0.16693
# min           1.00000     1.00000   1.00000   7.00000   1878.17000      325.50088      -800.00000         -24040.00000      -101.00000           -608.00000      -165.00000           -159.00000      -100.00000            -65.00000 234.00000 287.00000   745629.17925     1934.74618      0.97076   4.62478               9993.00000         -1310.39800     0.40555
# 25%           1.00000     1.00000   1.00000   7.00000   2622.40700      360.68088      -600.00000         -17752.00000        30.00000           -482.00000      -102.00000           -129.00000       -64.00000            -50.00000 235.00000 312.00000   913450.30228     2644.85391      0.99157   4.68813              13659.00000            -0.50100     0.43738
# 50%           1.00000     1.00000   1.00000   7.00000   3708.09700      396.88891      -556.00000         -17463.00000        63.00000           -422.00000       -81.00000           -115.00000       -53.00000            -39.00000 235.00000 320.00000  1523502.28890     3735.85699      0.99311   4.69790              18735.00000             0.00000     0.73750
# 75%           1.00000     1.00000   1.00000   7.00000   3767.57700      442.40891      -513.00000         -12271.00000        88.00000           -380.00000       -50.00000           -102.00000       -45.00000            -31.00000 236.00000 535.00000  1668172.13976     3792.55158      0.99423   4.71914              19165.00000             2.15700     0.75641
# max           1.00000     1.00000   1.00000   7.00000   5132.14300      478.95391      -201.00000          -8822.00000       187.00000           -264.00000         4.00000            -65.00000       -10.00000            -17.00000 236.00000 577.00000  2107380.44571     5148.54385      0.99754   4.73807              25502.00000          1765.67300     0.82230

# %%
y_analysis.head()
# Out:
#                      wahing_machine  dishwasher  oven  label label_str  ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary   Voltage   Current  instant_power  ApparentPower  PowerFactor     THD  HarmonicDistortionIndex  Power Fluctuations  Resistance
# 2023-01-01 00:00:00               0           0     0      0        AO     66.10700       67.08831        13.00000           -300.00000        16.00000            -55.00000       -16.00000            -21.00000        -6.00000             -8.00000 237.00000 279.00000     4435.00707       94.18586      0.70188 4.64394                435.00000             0.00000     0.84946
# 2023-01-01 00:00:01               0           0     0      0        AO     66.11600       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000             -8.00000 237.00000 279.00000     4436.47038       94.20144      0.70186 4.64518                437.00000             0.00900     0.84946
# 2023-01-01 00:00:02               0           0     0      0        AO     66.30900       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -13.00000 237.00000 281.00000     4449.42093       94.33700      0.70289 4.63423                442.00000             0.19300     0.84342
# 2023-01-01 00:00:03               0           0     0      0        AO     66.30900       67.10131        15.00000           -301.00000        17.00000            -54.00000       -16.00000            -22.00000        -6.00000            -15.00000 236.00000 281.00000     4449.42093       94.33700      0.70289 4.64903                446.00000             0.00000     0.83986
# 2023-01-01 00:00:04               0           0     0      0        AO     66.30900       65.99931        15.00000           -301.00000        16.00000            -54.00000       -16.00000            -22.00000        -9.00000            -15.00000 236.00000 281.00000     4376.34841       93.55636      0.70876 4.64932                448.00000             0.00000     0.83986

# %%
y_analysis.dtypes
# Out:
# wahing_machine               int64
# dishwasher                   int64
# oven                         int64
# label                        int64
# label_str                   object
# ActivePower                float64
# ReactivePower              float64
# harmonic1_Real             float64
# harmonic1_Imaginary        float64
# harmonic3_Real             float64
# harmonic3_Imaginary        float64
# harmonic5_Real             float64
# harmonic5_Imaginary        float64
# harmonic7_Real             float64
# harmonic7_Imaginary        float64
# Voltage                    float64
# Current                    float64
# instant_power              float64
# ApparentPower              float64
# PowerFactor                float64
# THD                        float64
# HarmonicDistortionIndex    float64
# Power Fluctuations         float64
# Resistance                 float64
# dtype: object

# %%
y = Y['label']

# %%
df.head()
# Out:
#                      ActivePower  ReactivePower   Voltage   Current  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary  wahing_machine  dishwasher    oven  dayofweek  dayofyear  year  month  quarter  hour  weekday  weekofyear  dayofmonth        date  season
# 2023-01-01 00:00:00     66.10700       67.08831 237.00000 279.00000        13.00000           -300.00000        16.00000            -55.00000       -16.00000            -21.00000        -6.00000             -8.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:01     66.11600       67.10131 237.00000 279.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000             -8.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:02     66.30900       67.10131 237.00000 281.00000        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -13.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:03     66.30900       67.10131 236.00000 281.00000        15.00000           -301.00000        17.00000            -54.00000       -16.00000            -22.00000        -6.00000            -15.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1
# 2023-01-01 00:00:04     66.30900       65.99931 236.00000 281.00000        15.00000           -301.00000        16.00000            -54.00000       -16.00000            -22.00000        -9.00000            -15.00000         0.00000     0.00000 0.00000          6          1  2023      1        1     0        6           0           1  2023-01-01       1

# %%
x_analysis = pd.concat([x_analysis, df['dayofweek'], df['dayofyear'], df['month'], df['hour'], df['weekday'], df['weekofyear'], df['dayofmonth'], df['season']], axis=1)

# %%
x_analysis.head()
# Out:
#                      ActivePower  ReactivePower  harmonic1_Real  harmonic1_Imaginary  harmonic3_Real  harmonic3_Imaginary  harmonic5_Real  harmonic5_Imaginary  harmonic7_Real  harmonic7_Imaginary   Voltage   Current  instant_power  ApparentPower  PowerFactor     THD  HarmonicDistortionIndex  Power Fluctuations  Resistance  dayofweek  dayofyear  month  hour  weekday  weekofyear  dayofmonth  season
# 2023-01-01 00:00:00     66.10700       67.08831        13.00000           -300.00000        16.00000            -55.00000       -16.00000            -21.00000        -6.00000             -8.00000 237.00000 279.00000     4435.00707       94.18586      0.70188 4.64394                435.00000             0.00000     0.84946          6          1      1     0        6           0           1       1
# 2023-01-01 00:00:01     66.11600       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000             -8.00000 237.00000 279.00000     4436.47038       94.20144      0.70186 4.64518                437.00000             0.00900     0.84946          6          1      1     0        6           0           1       1
# 2023-01-01 00:00:02     66.30900       67.10131        13.00000           -300.00000        17.00000            -55.00000       -16.00000            -22.00000        -6.00000            -13.00000 237.00000 281.00000     4449.42093       94.33700      0.70289 4.63423                442.00000             0.19300     0.84342          6          1      1     0        6           0           1       1
# 2023-01-01 00:00:03     66.30900       67.10131        15.00000           -301.00000        17.00000            -54.00000       -16.00000            -22.00000        -6.00000            -15.00000 236.00000 281.00000     4449.42093       94.33700      0.70289 4.64903                446.00000             0.00000     0.83986          6          1      1     0        6           0           1       1
# 2023-01-01 00:00:04     66.30900       65.99931        15.00000           -301.00000        16.00000            -54.00000       -16.00000            -22.00000        -9.00000            -15.00000 236.00000 281.00000     4376.34841       93.55636      0.70876 4.64932                448.00000             0.00000     0.83986          6          1      1     0        6           0           1       1

# %%
column_name = 'THD'

# Calculate the median of the column (excluding infinite values)
median_value = np.mean(x_analysis.replace([np.inf, -np.inf], np.nan)[column_name])

# Replace infinite values with the median in the specified column
x_analysis[column_name] = x_analysis[column_name].replace([np.inf, -np.inf, np.nan], median_value)

# Identify rows with infinite values in the specified column
rows_with_inf = x_analysis.index[np.isinf(x_analysis[column_name])]

# Print the rows containing infinite values for the specified column
print("Rows with infinite values in column '{}':".format(column_name))
print(rows_with_inf)
# Out:
# Rows with infinite values in column 'THD':
# DatetimeIndex([], dtype='datetime64[ns]', freq='s')

# %%
X = StandardScaler().fit_transform(x_analysis)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=25)

# %%
target_names = ['AO','OW','DW','DW_OW','WM','WM_OW','WM_DW','WM_DW_OW']

# %% [markdown]
# ## Random Forest Algorithm

# %%
class_weights = {0: 0.2, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0, 5: 1.0, 6: 1.0, 7: 3.0}

# Initialize RandomForestClassifier with custom class weights
clf_frst = RandomForestClassifier(n_estimators=500, class_weight=class_weights, random_state=0)

# scores = cross_val_score(clf_frst, X, y, cv=kf)
# print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))

# %%
clf_frst.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.2, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0,
#                                      5: 1.0, 6: 1.0, 7: 3.0},
#                        n_estimators=500, random_state=0)

# %%
prediction = clf_frst.predict(X)

# %%
print(classification_report(y, prediction, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           AO       1.00      1.00      1.00   8501970
#           OW       1.00      1.00      1.00     69501
#           DW       1.00      1.00      1.00    182445
#        DW_OW       1.00      1.00      1.00     20340
#           WM       1.00      1.00      1.00    238119
#        WM_OW       1.00      1.00      1.00     21308
#        WM_DW       1.00      1.00      1.00     37804
#     WM_DW_OW       1.00      1.00      1.00       513
#
#     accuracy                           1.00   9072000
#    macro avg       1.00      1.00      1.00   9072000
# weighted avg       1.00      1.00      1.00   9072000

# %%
prediction_test = clf_frst.predict(X_test)

# %%
print(classification_report(y_test, prediction_test, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           AO       1.00      1.00      1.00   1700394
#           OW       1.00      1.00      1.00     13900
#           DW       1.00      1.00      1.00     36489
#        DW_OW       1.00      1.00      1.00      4068
#           WM       0.98      0.98      0.98     47624
#        WM_OW       1.00      1.00      1.00      4262
#        WM_DW       1.00      1.00      1.00      7561
#     WM_DW_OW       1.00      1.00      1.00       102
#
#     accuracy                           1.00   1814400
#    macro avg       1.00      1.00      1.00   1814400
# weighted avg       1.00      1.00      1.00   1814400

# %%
result_df = pd.DataFrame({'Actual': y_test, 'Predicted': prediction_test})

# %%
from sklearn.metrics import accuracy_score

# Assuming X_test and y_test are your testing data
baseline_predictions = prediction_test
baseline_accuracy = accuracy_score(y_test, baseline_predictions)
print(f"Baseline Accuracy: {baseline_accuracy:.4f}")
# Out:
# Baseline Accuracy: 0.9989

# %%
clf_frst.feature_importances_
# Out:
# array([0.0575, 0.0588, 0.0183, 0.0599, 0.0561, 0.0609, 0.1   , 0.0815,
#        0.1118, 0.0446, 0.0016, 0.0173, 0.0992, 0.0857, 0.0131, 0.0088,
#        0.0645, 0.0038, 0.0166, 0.0039, 0.0066, 0.0015, 0.0118, 0.004 ,
#        0.0041, 0.0072, 0.0006])

# %%
# features = x_analysis.columns
features = x_analysis.columns
importances = clf_frst.feature_importances_
indices = np.argsort(importances)

plt.title('Feature importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative importance')
plt.show()

# %%
cm = pd.DataFrame(confusion_matrix(y, prediction), index=target_names, columns=target_names)
cm
# Out:
#                AO     OW      DW  DW_OW      WM  WM_OW  WM_DW  WM_DW_OW
# AO        8500822      0      15      0    1133      0      0         0
# OW              8  69493       0      0       0      0      0         0
# DW             79      1  182365      0       0      0      0         0
# DW_OW           0      0       1  20339       0      0      0         0
# WM            997      3       0      0  237118      1      0         0
# WM_OW           0      1       0      0       2  21305      0         0
# WM_DW           0      0       0      0       0      0  37804         0
# WM_DW_OW        0      0       0      0       0      0      0       513
